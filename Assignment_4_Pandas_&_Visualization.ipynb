# %% [markdown]
# <a href="https://colab.research.google.com/github/rakshithaelango/Pandas-Visualization/blob/main/Assignment_4_Pandas_%26_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Assessment**
#
# I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems
#
# **import necessary libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **merge those two csv files (after getting as dataframes, get them as a single dataframe)**

# %%
# first csv.file
col1 = pd.read_csv('/content/college_1.csv')

# %%
col1
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
# first 5 rows
col1.head()
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
# 3  Mugunthan S   100.0   47.0              10610           10610
# 4  Sathammai.S   100.0    8.0               8980            8980
#
#                          Department  Rising
# 0  Computer Science and Engineering       0
# 1  Computer Science and Engineering       0
# 2  Computer Science and Engineering       0
# 3  Computer Science and Engineering       0
# 4  Computer Science and Engineering       0

# %%
# last 5 rows
col1.tail()
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 79  Electronics and Electrical Engineering       0
# 80  Electronics and Electrical Engineering       0
# 81  Electronics and Electrical Engineering       0
# 82  Electronics and Electrical Engineering       0
# 83  Electronics and Electrical Engineering       0

# %%
# no of rows and columns
col1.shape
# Out:
# (84, 7)

# %%
#read 2 nd csv file
col2=pd.read_csv('/content/college_2.csv')

# %%
# first 5 rows
col2.head()
# Out:
#                 Name  python  python_en  mysql  computational_thinking  \
# 0      ASHOK KUMAR K     100          0     31                       9
# 1            Chandru       0         20      0                       0
# 2  Ganesh Ramkumar R      -1         55     24                       6
# 3    Bodipudi Harini      -1          0     35                      -1
# 4          VIINU V P      -1        100     24                      -1
#
#    Previous Geekions  CodeKata Score  \
# 0              19400           19400
# 1              14150           14490
# 2               8790           10790
# 3              10040           10040
# 4               9150            9150
#
#                                   Department  Rising
# 0     Electronics and Electrical Engineering       0
# 1           Computer Science and Engineering     340
# 2           Computer Science and Engineering    2000
# 3  Electronics and Communication Engineering       0
# ...

# %%
# last 5 rows
col2.tail()
# Out:
#              Name  python  python_en  mysql  computational_thinking  \
# 30  praveen raj j      24         -1      0                       0
# 31     AMARNATH D      -1         52     12                      -1
# 32           bala      32         49      0                      -1
# 33           XY Z      -1         20     -1                      -1
# 34      Hariharan      -1         -1     -1                       0
#
#     Previous Geekions  CodeKata Score  \
# 30               2380            2380
# 31               1890            1890
# 32               1720            1720
# 33                  0               0
# 34                  0               0
#
#                                    Department  Rising
# 30           Computer Science and Engineering       0
# 31  Electronics and Communication Engineering       0
# 32  Electronics and Communication Engineering       0
# 33           Computer Science and Engineering       0
# ...

# %%
# no of rows and col
col2.shape
# Out:
# (35, 9)

# %%
#merging 2 table
df=pd.concat([col1,col2])
df
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %%
#shape of the table after merging
df.shape
# Out:
# (119, 9)

# %% [markdown]
# **Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)**
#
# **consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv**

# %%
df.columns
# Out:
# Index(['Name', 'python', 'mysql', 'Previous Geekions', 'CodeKata Score',
#        'Department', 'Rising', 'python_en', 'computational_thinking'],
#       dtype='object')

# %%
#codekata score exceeds 15000 in first csv file
exceed=col1[['CodeKata Score']]>15000
exceed
# Out:
#     CodeKata Score
# 0             True
# 1             True
# 2             True
# 3            False
# 4            False
# ..             ...
# 79           False
# 80           False
# 81           False
# 82           False
# 83           False
#
# [84 rows x 1 columns]

# %%
#create and save values into Exceeded expectations.csv 
exceed.to_csv('Exceeded expectations.csv',index=False)

# %%
#codekata score exceeds 15000 in second csv file
exceed2=col2[['CodeKata Score']]>15000
exceed2
# Out:
#     CodeKata Score
# 0             True
# 1            False
# 2            False
# 3            False
# 4            False
# 5            False
# 6            False
# 7            False
# 8            False
# 9            False
# 10           False
# 11           False
# 12           False
# 13           False
# 14           False
# 15           False
# 16           False
# 17           False
# 18           False
# 19           False
# 20           False
# 21           False
# 22           False
# 23           False
# 24           False
# 25           False
# 26           False
# 27           False
# 28           False
# 29           False
# 30           False
# 31           False
# 32           False
# 33           False
# 34           False

# %%
#create and save values into Exceeded expectations2.csv  for 2nd csv file
exceed.to_csv('Exceeded expectations2.csv',index=False)

# %% [markdown]
# **if 10000<codekata score<15000 (Reached_expectations.csv)**

# %%
# file 1 : if 10000<codekata score<15000 (Reached_expectations.csv)
reached=col1[col1['CodeKata Score'].between(10000,15000,inclusive="right")]
reached
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 3  Mugunthan S   100.0   47.0              10610           10610
#
#                          Department  Rising
# 3  Computer Science and Engineering       0

# %%
#create and save values into Exceeded expectations.csv  for 1nd csv file
reached.to_csv('Reached expectations.csv',index=False)

# %%
# file 2 : if 10000<codekata score<15000 (Reached_expectations.csv)
reached2=col2[col2['CodeKata Score'].between(10000,15000,inclusive="right")]
reached2
# Out:
#                 Name  python  python_en  mysql  computational_thinking  \
# 1            Chandru       0         20      0                       0
# 2  Ganesh Ramkumar R      -1         55     24                       6
# 3    Bodipudi Harini      -1          0     35                      -1
#
#    Previous Geekions  CodeKata Score  \
# 1              14150           14490
# 2               8790           10790
# 3              10040           10040
#
#                                   Department  Rising
# 1           Computer Science and Engineering     340
# 2           Computer Science and Engineering    2000
# 3  Electronics and Communication Engineering       0

# %%
#create and save values into Exceeded expectations.csv  for 2nd csv file
reached2.to_csv('Reached expectations2.csv',index=False)

# %% [markdown]
# **if 7000<codekata score<10000 (Needs_Improvement.csv)**

# %%
# 1 : if 10000<codekata score<15000 (Reached_expectations.csv)
improvement=col1[col1['CodeKata Score'].between(7000,10000,inclusive="right")]
improvement
# Out:
#                    Name  python  mysql  Previous Geekions  CodeKata Score  \
# 4           Sathammai.S   100.0    8.0               8980            8980
# 5          NIVEESHWAR S   100.0    0.0               8200            8200
# 6         KALAIARASAN K    85.0   47.0               7750            7880
# 7  MOHAMED ZUBAIR AHMED    82.0    4.0               7020            7020
#
#                                   Department  Rising
# 4           Computer Science and Engineering       0
# 5           Computer Science and Engineering       0
# 6  Electronics and Communication Engineering     130
# 7           Computer Science and Engineering       0

# %%
#create and save values into Needs_Improvement.csv  for 1nd csv file
improvement.to_csv('Needs_Improvement.csv',index=False)

# %%
# file 2 : if 10000<codekata score<15000 (Reached_expectations.csv)
improvement2=col2[col2['CodeKata Score'].between(7000,10000,inclusive="right")]
improvement2
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# 11    Balaraman Muthupandi      -1          9      0                       0
# 12                JPradhap     100          0      0                       0
# 13           SRIRAMKUMAR B      -1          0      0                       0
# 14               Praneetha      -1         23    100                      -1
# ...

# %%
#create and save values into Needs_Improvement2.csv 
improvement2.to_csv('Needs_Improvement2.csv',index=False)

# %% [markdown]
# **if codekate score < 7000 (Unsatisfactory.csv)**

# %%
# CSV file 1 : if codekata score<7000 (Unsatisfactory.csv)
unsatisfactory=col1[col1['CodeKata Score']<7000]
unsatisfactory
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8        J.SUGANTHI    27.0  50.00               5860            5860
# 9      thamizhpaana    29.0   0.00               5500            5500
# 10  Iyappan Samiraj    50.0  24.00               5400            5400
# 11     Ponniyamma.R   100.0  11.25               5380            5380
# 12        SABAPATHI   100.0   0.00               5280            5280
# ..              ...     ...    ...                ...             ...
# 79     KarthikeyanS    45.0   0.00                  0               0
# 80         BARATH.P    29.0   0.00                  0               0
# 81    N.Ajith kumar    82.0   0.00                  0               0
# 82     mohamed nabi     0.0   0.00                  0               0
# 83   yaser ahamed.A     0.0  27.00                  0               0
#
#                                    Department  Rising
# 8   Electronics and Communication Engineering       0
# ...

# %%
#for 1 st csv file store in unsatisfactory.csv
unsatisfactory.to_csv('unsatsfactory.csv',index=False)

# %%
# CSV file 2 : if codekata score<7000 (Unsatisfactory.csv)
unsatisfactory2=col2[col2['CodeKata Score']<7000]
unsatisfactory2
# Out:
#                  Name  python  python_en  mysql  computational_thinking  \
# 18     Narasimhan Y L      -1         -1      0                       0
# 19       Leelakrishna      -1          6      4                       0
# 20     PremsagarReddy      -1         20      0                       0
# 21          pradeeban      16         20     24                       0
# 22        santhoshini      -1         43      0                       0
# 23         MUKESH S M      -1         46      0                       0
# 24      P.GOVARDHANAN      -1         40      0                      -1
# 25       SHAIK DANISH      -1         43      0                       0
# 26          sridhar.s      -1         52      0                       0
# 27  Vimalesh Fernando      -1          0      0                       0
# 28      M.Karthikeyan      -1          0      4                       6
# 29          Abishak s      -1         55     35                       6
# ...

# %%
#for 2nd csv file store in unsatisfactory2.csv
unsatisfactory.to_csv('unsatsfactory2.csv',index=False)

# %% [markdown]
# **Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)**

# %%
df['Average']=(df['Previous Geekions']+df['CodeKata Score'])/2
df['Average']=df['Average'].astype('int32')

# %%
df.head()
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
# 3  Mugunthan S   100.0   47.0              10610           10610
# 4  Sathammai.S   100.0    8.0               8980            8980
#
#                          Department  Rising  python_en  \
# 0  Computer Science and Engineering       0        NaN
# 1  Computer Science and Engineering       0        NaN
# 2  Computer Science and Engineering       0        NaN
# 3  Computer Science and Engineering       0        NaN
# 4  Computer Science and Engineering       0        NaN
#
#    computational_thinking  Average
# 0                     NaN    24500
# 1                     NaN    21740
# 2                     NaN    19680
# 3                     NaN    10610
# 4                     NaN     8980

# %% [markdown]
# **No of students participated**

# %%
df['Name'].count()
# Out:
# 119

# %% [markdown]
# **Average completion of python course or my_sql or python english or computational thinking**

# %%
#cheking for null value
print(col1[col1['python'].isnull()])
print(col1[col1['mysql'].isnull()])
# Out:
# Empty DataFrame
# Columns: [Name, python, mysql, Previous Geekions, CodeKata Score, Department, Rising]
# Index: []
# Empty DataFrame
# Columns: [Name, python, mysql, Previous Geekions, CodeKata Score, Department, Rising]
# Index: []

# %%
#checking null value of college 2
print(col2[col2['python'].isnull()])
print(col2[col2['mysql'].isnull()])
print(col2[col2['python_en'].isnull()])
print(col2[col2['computational_thinking'].isnull()])
# Out:
# Empty DataFrame
# Columns: [Name, python, python_en, mysql, computational_thinking, Previous Geekions, CodeKata Score, Department, Rising]
# Index: []
# Empty DataFrame
# Columns: [Name, python, python_en, mysql, computational_thinking, Previous Geekions, CodeKata Score, Department, Rising]
# Index: []
# Empty DataFrame
# Columns: [Name, python, python_en, mysql, computational_thinking, Previous Geekions, CodeKata Score, Department, Rising]
# Index: []
# Empty DataFrame
# Columns: [Name, python, python_en, mysql, computational_thinking, Previous Geekions, CodeKata Score, Department, Rising]
# Index: []

# %%
col1['python'].unique()
# Out:
# array([ 82. , 100. ,  85. ,  27. ,  29. ,  50. ,  56. ,  32. ,  87.5,
#         16. ,  74. ,  53. ,  93. ,   0. ,   3. ,  43. ,  11. ,  61. ,
#         97.5,  30. ,  95. ,  45. ])

# %%
col1['mysql'].unique()
# Out:
# array([ 20.  , 100.  ,  47.  ,   8.  ,   0.  ,   4.  ,  50.  ,  24.  ,
#         11.25,  12.  ,  35.  ,  77.  ,  86.25,  39.  ,  28.75,   7.5 ,
#         27.  ,   3.75])

# %%
print(col1[['python','mysql']].mean())
# Out:
# python    73.392857
# mysql     27.601190
# dtype: float64

# %%
col2['python'].unique()
# Out:
# array([100,   0,  -1,  58,  16,  24,  32])

# %%
col2['mysql'].unique()
# Out:
# array([ 31,   0,  24,  35,   4,  20,  62, 100,  12,  -1])

# %%
col2['python_en'].unique()
# Out:
# array([  0,  20,  55, 100,  78,  60,  15,   9,  23,  72,  63,  -1,   6,
#         43,  46,  40,  52,  49])

# %%
col2['computational_thinking'].unique()
# Out:
# array([ 9,  0,  6, -1,  3, 39])

# %%
# many values are -1 in pyhton, mysql,python_en,computational thinking it will affect mean value so replace with nan
clm = ['python','mysql','python_en','computational_thinking']
col2[clm]=col2[clm].replace(-1,np.nan)

# %%
#successfully replace with nan
col2
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K   100.0        0.0   31.0                     9.0
# 1                  Chandru     0.0       20.0    0.0                     0.0
# 2        Ganesh Ramkumar R     NaN       55.0   24.0                     6.0
# 3          Bodipudi Harini     NaN        0.0   35.0                     NaN
# 4                VIINU V P     NaN      100.0   24.0                     NaN
# 5               Poojitha Y     0.0       78.0   35.0                     0.0
# 6   Gowtham Chandrasekaran     NaN        0.0    0.0                     3.0
# 7                Gowtham R     NaN       60.0    4.0                     6.0
# 8                 shifak N    58.0        0.0    0.0                     0.0
# 9                  Balaji      NaN      100.0   20.0                     0.0
# 10                Rushitha     NaN       15.0   62.0                     9.0
# ...

# %%
col2[['python','mysql','python_en','computational_thinking']].mean()
# Out:
# python                    41.250000
# mysql                     14.545455
# python_en                 32.531250
# computational_thinking     3.000000
# dtype: float64

# %%
# calculating both college 1 and college 2 average
new_df=pd.concat([col1,col2])

# %%
new_df[['python','mysql','python_en','computational_thinking']].mean()
# Out:
# python                    70.597826
# mysql                     23.918803
# python_en                 32.531250
# computational_thinking     3.000000
# dtype: float64

# %% [markdown]
# **Rising star of the week (top 3 candidate who performed well in that particular week)**

# %%
df.nlargest(3,'CodeKata Score')
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  \
# 0  Computer Science and Engineering       0        NaN
# 1  Computer Science and Engineering       0        NaN
# 2  Computer Science and Engineering       0        NaN
#
#    computational_thinking  Average
# 0                     NaN    24500
# 1                     NaN    21740
# 2                     NaN    19680

# %% [markdown]
# **Shining stars of the week (top 3 candidates who has highest geekions)**

# %%
df.nlargest(3,'Previous Geekions')
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  \
# 0  Computer Science and Engineering       0        NaN
# 1  Computer Science and Engineering       0        NaN
# 2  Computer Science and Engineering       0        NaN
#
#    computational_thinking  Average
# 0                     NaN    24500
# 1                     NaN    21740
# 2                     NaN    19680

# %% [markdown]
# **Department wise codekata performence (pie chart)**

# %%
df.Department.unique()
# Out:
# array(['Computer Science and Engineering',
#        'Electronics and Communication Engineering',
#        'Electronics and Electrical Engineering'], dtype=object)

# %%
dep_score=df.groupby('Department')['CodeKata Score'].sum()
dep_score
# Out:
# Department
# Computer Science and Engineering             320025
# Electronics and Communication Engineering    108335
# Electronics and Electrical Engineering        53800
# Name: CodeKata Score, dtype: int64

# %%
plt.pie(dep_score.values,labels=dep_score.index,autopct='%.0f%%')
plt.show()

# %% [markdown]
# **Department wise toppers (horizantal bar graph or any visual representations of your choice)**

# %%
topper= pd.DataFrame(df.groupby('Department')['CodeKata Score'].nlargest(1))

# %%
topper=topper.droplevel(level=1)
topper
# Out:
#                                            CodeKata Score
# Department
# Computer Science and Engineering                    24500
# Electronics and Communication Engineering           10040
# Electronics and Electrical Engineering              19400

# %%
topper=topper.sort_values(by='CodeKata Score')

# %%
topper.plot(kind='barh', color='blue')
plt.xlabel('CodeKata Score')
# Out:
# Text(0.5, 0, 'CodeKata Score')
